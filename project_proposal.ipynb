# %% [markdown]
# ### Capstone Project Proposal (Module 3.6)
# ### Phai Phongthiengtham

# %% [markdown]
# ### How do successful firms post their job vacancies for managers?

# %% [markdown]
# #### Broad Idea:
# Management has been long emphasized as an important factor of the success of a company. Nevertheless, there is little empirical evidence mostly due to limited data. This project contributes to the literature by looking at what successful firms are looking for when they hire a manager.  Using 15 millions of management job postings all over the US from 2012-2016, the objective is to explore what features of management job postings can predict a firm’s performance (for example, profitability, stock market movement).

# %% [markdown]
# #### Potential Clients:
# * Human resource departments
# * Job board websites
#
# #### Data:
# (1.) Vacancy postings
#
# Vacancy postings are provided by CareerBuilder. This project uses all management postings in the US from 2012-2016. Management positions are defined by the occupation code provided by the Bureau of Labor Statistics.
#
# Relevant variables are:
#
# * posting period: month, year
# * geographic information: city, state, zip code, county
# * firm information: firm's name, NAICS
# * posting information: job title, education, occupation code and original content of the posting

# %%
import pandas as pd
pd.set_option('display.max_columns', 200)

# --- Data Description: Job Postings --- 
#
#
# all variable names for CB job postings
FieldList = ['obs','yearmonth', 'city', 'state', 'zip', 'county',
             'company_name', 'company_naics', 'company_isstaffingfirm',
             'master_company_name', 'master_company_naics', 'master_company_isstaffingfirm',
             'onet', 'cb_jobtitle_id', 'cb_jobtitle', 'edulevels_name',
             'source', 'subsource', 'original_jobtitle', 'url', 'description']
# read postings
df_postings = pd.read_csv('postings/raw/Data_2012.txt',sep='|',names = FieldList)
# select relevant variables
df_postings = df_postings[['obs','yearmonth','city','state','county',
                           'company_name','company_naics',
                           'master_company_name', 'master_company_naics',
                           'edulevels_name', 'onet','cb_jobtitle','description']]

df_postings = df_postings.rename(columns={'company_naics': 'naics'})

# set index
df_postings = df_postings.set_index(['obs','yearmonth'])

# %%
df_postings.head()
# Out:
#                          city state  county                     company_name  \
# obs yearmonth
# 11  201201      Oak Brook, IL    IL   17043   Inland Real Estate Corporation
# 16  201201        Chicago, IL    IL   17031              Memorial Health Inc
# 20  201201        Houston, TX    TX   48201  Oceaneering International, Inc.
# 22  201201         Denver, CO    CO    8031        P2 Energy Solutions, Inc.
# 30  201201     Sacramento, CA    CA    6067            The McClatchy Company
#
#                   naics              master_company_name  \
# obs yearmonth
# 11  201201     531110.0   Inland Real Estate Corporation
# 16  201201     621999.0              Memorial Health Inc
# 20  201201     213112.0  Oceaneering International, Inc.
# 22  201201     213112.0        P2 Energy Solutions, Inc.
# 30  201201     511110.0            The McClatchy Company
#
#                master_company_naics  \
# obs yearmonth
# 11  201201                 531110.0
# 16  201201                 621999.0
# 20  201201                 213112.0
# 22  201201                 213112.0
# 30  201201                 511110.0
#
#                                             edulevels_name        onet  \
# obs yearmonth
# 11  201201     ['High school or GED', "Bachelor's degree"]  11-2022.00
# 16  201201                           ["Bachelor's degree"]  11-3021.00
# 20  201201                           ["Bachelor's degree"]  11-9041.00
# 22  201201        ["Bachelor's degree", "Master's degree"]  11-2021.00
# 30  201201                                              []  11-2021.00
#
#                                         cb_jobtitle  \
# obs yearmonth
# 11  201201            Business Development Managers
# 16  201201     Information Technology (IT) Managers
# 20  201201                         Project Managers
# 22  201201                         Product Managers
# 30  201201                       Marketing Managers
#
#                                                      description
# obs yearmonth
# 11  201201     The Inland Real Estate Group of Companies, Inc...
# 16  201201     Title : Director of Applications Information T...
# 20  201201     Company Profile Oceaneering is a global oilfie...
# 22  201201     P2 Energy Solutions seeks a Senior Product Man...
# 30  201201     The McClatchy Company, the third-largest newsp...

# %%
df_postings['description'][0] # example of original posting content
# Out:
# "The Inland Real Estate Group of Companies, Inc currently has a full-time opening for a Director of Leasing for one of the Inland REIT ' s. This position will oversee and direct one of the Inland REIT ' s leasing policies and strategies within a retail portfolio. Additional responsibilities include directing the day to day leasing functions and activities through delegation and may also assist with complex leasing transactions. This position will be base din Oak Brook, IL and qualified candidates should have more than 10 years successful commercial leasing experience, preferably within the retail environment. Job Functions : Manage leasing functions thru Leasing Agent Provide industry training to Leasing Agents Oversee productivity of Leasing Agents Provide direction on deal terms to the Leasing Agents Set deal thresholds for Leasing Agents Coordinate with the Marketing Department and Leasing Agents portfolio based marketing efforts Coordinate Retailer presentations Coordinate with the Marketing Department and Leasing Agents trade show participation Supervise Lease process with Lease Coordinator and Attorneys Negotiate final terms and lease documents with perspective Retailers Demonstrates company mission statement, integrity, respect, innovation, dedication and excellence Reads, analyzes and interprets general business periodicals and professional journals Writes reports and business correspondence Effectively presents information and responds to questions from management, co-workers, tenants and vendors. Requirements : 10 + years of Retail Leasing experience High School Degree ( Bachelors Degree preferred ) Current, valid state drivers license and the ability to travel. Must be computer literate in modern business applications Local candidates preferred To apply, please click the ' Apply Now ' tab or you can visit this opening on our Careers page at WWW. inland group. com to apply."

# %%
df_postings['description'][1] # example of original posting content
# Out:
# 'Title : Director of Applications Information Technology Location : Savannah, GA Description : Memorial Health has an immediate need for a Director of Applications in Savannah, GA. This is a great opportunity for the right candidate to deliver, develop, and implement business and clinical applications. Responsibilities : Responsible for overseeing the performance of several departments focused on different application portfolios and limited software development. Translates client requirements into applications that create business value and actively promote the use of the application to end-users. Assists in the development and implementation of the application strategy and communicates the value of technology / applications to clients. Provides direction and leadership in the review of present IT systems and methods, while forming new and revised systems. Demonstrates creative IT solutions for resolving complex business issues within the organization. Assesses potential technological alternatives as solutions for resolving the business automation issues through critical thinking and complex solving analysis. Participates in the IS management team to set the direction of the IT Division. Collaborates on the budgetary and staff allocations, adoption of new technologies, and resolution of the business automation process. Leads, reviews, and approves trade-off analysis on architectural decisions, selecting appropriately from standards, tools, and applications. Mentors architects and senior application leaders in following a strategy that fits the application direction. Creates and establishes a team of high-performing application managers and staff. Ensures workflow and application positions are designed to maximize effectiveness. Ensures change management, application management, and industry standards are maintained and implemented. . Requirements : Bachelors Degree is required in Management, Business, Information Technology, Science, Engineering, or other related fields. ITIL Version 3 Certification is required 8 years experience working with IT and 2 years healthcare IT experience. Preferred : Previous consulting experience is preferred Benefits : Comprehensive Relocation Assistance Medical Dental Vision Fitness Center Membership Tuition Assistance Paid Time Off / Plus Security ( Paid Sick Leave )'

# %% [markdown]
# (2.) COMPUSTAT (North America) Database provided by Wharton Research Data Services
#
# All publicly traded companies in the US are required to track accounting and balance sheet
# data. Compustat datbase, therefore, provides excellent information on firms. Full compustat dataset contains 1,842 variables. Potential relevant variables include:
#
# * North American Industry Classification Code (NAICS)
# * Company name (CONM)
# * Company legal name (CONML)
# * Earnings before interest and taxes (EBIT)
# * Earnings per share (EPSFI)
# * Book value per share (BVLPS)
# * Market value (MKVALT)
# * Net income (NI)
#
# There are additional information on stock prices as well (coming soon).

# %%
# --- Data Description: Compustat --- 
#
#
# compustat data
df_compustat = pd.read_csv('compustat/compustat_extracted_small.txt',sep='\t')
df_compustat.head(10)
# Out:
#     bkvlps                         conm                        conml     ebit  \
# 0  21.4697                     AAR CORP                     AAR Corp   142.36
# 1  23.3254                     AAR CORP                     AAR Corp   136.60
# 2  25.2654                     AAR CORP                     AAR Corp   142.60
# 3  23.8574                     AAR CORP                     AAR Corp    -8.60
# 4  25.0847                     AAR CORP                     AAR Corp    66.10
# 5 -23.8210  AMERICAN AIRLINES GROUP INC  American Airlines Group Inc   494.00
# 6 -10.4608  AMERICAN AIRLINES GROUP INC  American Airlines Group Inc  1935.00
# 7   2.8976  AMERICAN AIRLINES GROUP INC  American Airlines Group Inc  5073.00
# 8   9.0215  AMERICAN AIRLINES GROUP INC  American Airlines Group Inc  7284.00
# 9   7.4612  AMERICAN AIRLINES GROUP INC  American Airlines Group Inc  6007.00
#
#    epsfi      mkvalt   naics        ni
# 0   1.65    485.2897  423860    67.723
# 1   1.38    790.0029  423860    55.000
# 2   1.83    961.3080  423860    72.900
# 3   0.24   1046.3954  423860    10.200
# 4   1.37    842.5112  423860    47.700
# 5  -5.60    266.5571  481111 -1876.000
# 6 -11.25   6591.9923  481111 -1834.000
# 7   3.93  37405.5843  481111  2882.000
# 8  11.07  26452.7417  481111  7610.000
# 9   4.81  23685.5569  481111  2676.000

# %% [markdown]
# Firm performance indicator:
# * Change in net income (YoY)
# * Change in earnings per share (YoY)
# * Change in stock prices
